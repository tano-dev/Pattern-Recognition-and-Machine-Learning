# %% [markdown]
# # Lab 05 - Bài tập

# %%
# Import các thư viện thông dụng
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import các distribution packages từ thư viện scipy
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import t

# %% [markdown]
# **Bài 01:** Một bài thi trắc nghiệm gồm 10 câu hỏi, mỗi câu có 4 phương án trả lời trong đó chỉ có một phương án đúng. Bạn hãy:
#
# a. Một sinh viên không học bài làm bài bằng cách chọn ngẫu nhiên một phương án cho mỗi câu hỏi. Bạn hãy dùng hàm random để in ra số câu đúng của bạn sinh viên trong 10 lần kiểm tra.
#
# b. Giả sử mỗi câu đúng được 4 điểm, mỗi câu sai bị trừ 2 điểm. Tính xác suất để sinh viên này được 4 điểm
#
# c. Gọi X là số câu trả lời đúng. Tính E(X) và Var(X)

# %%
# **Bài 01:** Một bài thi trắc nghiệm gồm 10 câu hỏi, mỗi câu có 4 phương án trả lời trong đó chỉ có một phương án đúng. Bạn hãy: 

# a. Một sinh viên không học bài làm bài bằng cách chọn ngẫu nhiên một phương án cho mỗi câu hỏi. Bạn hãy dùng hàm random để in ra số câu đúng của bạn sinh viên trong 10 lần kiểm tra.

# b. Giả sử mỗi câu đúng được 4 điểm, mỗi câu sai bị trừ 2 điểm. Tính xác suất để sinh viên này được 4 điểm

# c. Gọi X là số câu trả lời đúng. Tính E(X) và Var(X)

#a


n = 10  # Số câu hỏi
p = 0.25  # Xác suất trả lời đúng mỗi câu hỏi
size = 10  # Số lần kiểm tra
correct_answers = binom.rvs(n, p, size=size)
print("Số câu đúng trong 10 lần kiểm tra:", correct_answers)

#b
# Tính số câu đúng cần thiết để được 4 điểm
score_needed = 4
# 4x - 2(10 - x) = 4 => 6x - 20 = 4 => 6x = 24 => x = 4
probability = binom.pmf(4, n, p)
print(f"Xác suất để sinh viên được {score_needed} điểm:", probability)

#c
expected_value = n * p
variance = n * p * (1 - p)
print("E(X):", expected_value)
print("Var(X):", variance)
# E(X) = x * p = 10 * 0.25 = 2.5
# Var(X) = n * p * (1 - p) = 10 * 0.25 * 0.75 = 1.875
# Out:
# Số câu đúng trong 10 lần kiểm tra: [4 2 3 2 2 2 0 3 2 4]
# Xác suất để sinh viên được 4 điểm: 0.14599800109863273
# E(X): 2.5
# Var(X): 1.875

# %% [markdown]
# **Bài 02:** Một trung tâm bưu điện nhận được 3 cuộc gọi điện thoại mỗi phút. Tính xác suất để trung tâm nhận được 1 cuộc gọi, 2 cuộc gọi, 3 cuộc gọi trong vòng một phút biết số cuộc gọi trong một phút có phân phối Poisson.

# %%
# **Bài 02:** Một trung tâm bưu điện nhận được 3 cuộc gọi điện thoại mỗi phút. Tính xác suất để trung tâm nhận được 1 cuộc gọi, 2 cuộc gọi, 3 cuộc gọi trong vòng một phút biết số cuộc gọi trong một phút có phân phối Poisson.

# 1 cuộc:
lambda_poisson = 3  # Số cuộc gọi trung bình mỗi phút
prob_1_call = poisson.pmf(1, lambda_poisson)
print("Xác suất nhận được 1 cuộc gọi trong một phút:", prob_1_call)
# 2 cuộc:
prob_2_calls = poisson.pmf(2, lambda_poisson)
print("Xác suất nhận được 2 cuộc gọi trong một phút:", prob_2_calls)
# 3 cuộc:
prob_3_calls = poisson.pmf(3, lambda_poisson)
print("Xác suất nhận được 3 cuộc gọi trong một phút:", prob_3_calls)
# Out:
# Xác suất nhận được 1 cuộc gọi trong một phút: 0.14936120510359185
# Xác suất nhận được 2 cuộc gọi trong một phút: 0.22404180765538775
# Xác suất nhận được 3 cuộc gọi trong một phút: 0.22404180765538775

# %% [markdown]
# **Bài 03:** Trọng lượng (đơn vị gam) của một loại trái cây có phân phối chuẩn với µ = 500 (gam) gam và $σ^2 = 16 (gam^2)$. Trái cây thu hoạch được phân loại theo trọng lượng như sau:
#
# Loại 1: trên 505 gam
#
# Loại 2: từ 495 – 505 gam
#
# Loại 3: dười 495 gam
#
# - a. Hãy tính tỷ lệ của mỗi loại.
# - b. Bạn hãy mô phỏng lấy mẫu  20 trái cây trên. Bạn hãy vẽ histogram trọng lượng trái cây và tính giá trị trung bình và độ lệch chuẩn trái cây từ mẫu
# - c. Bạn hãy mô phỏng lấy 100 trái cây trên. Bạn hãy vẽ histogram trọng lượng trái cây và tính giá trị trung bình và độ lệch chuẩn trái cây từ mẫu
# - d. Từ hai cách lấy mẫu ở câu b, c bạn có nhận xét gì không?

# %%
# **Bài 03:** Trọng lượng (đơn vị gam) của một loại trái cây có phân phối chuẩn với µ = 500 (gam) gam và $σ^2 = 16 (gam^2)$. Trái cây thu hoạch được phân loại theo trọng lượng như sau:

# Loại 1: trên 505 gam

# Loại 2: từ 495 – 505 gam

# Loại 3: dười 495 gam

# a. Hãy tính tỷ lệ của mỗi loại.
# b. Bạn hãy mô phỏng lấy mẫu  20 trái cây trên. Bạn hãy vẽ histogram trọng lượng trái cây và tính giá trị trung bình và độ lệch chuẩn trái cây từ mẫu
# c. Bạn hãy mô phỏng lấy 100 trái cây trên. Bạn hãy vẽ histogram trọng lượng trái cây và tính giá trị trung bình và độ lệch chuẩn trái cây từ mẫu
# d. Từ hai cách lấy mẫu ở câu b, c bạn có nhận xét gì không?


mu = 500  # Trung bình
sigma = 4  # Độ lệch chuẩn

#a
p_1 = 1 - norm.cdf(505, mu, sigma)
p_2 = norm.cdf(505, mu, sigma) - norm.cdf(495, mu, sigma)
p_3 = norm.cdf(495, mu, sigma)
print("Tỷ lệ loại 1 (trên 505 gam):", p_1)
print("Tỷ lệ loại 2 (từ 495 – 505 gam):", p_2)
print("Tỷ lệ loại 3 (dưới 495 gam):", p_3)
#b 
data_b = norm.rvs(loc=mu, scale=sigma, size=20)

dorongcot=1
offset = dorongcot/2  # Dùng để hiển thị ngay dấu ticks

plt.hist(data_b, bins=10, width=dorongcot)
plt.title("Histogram of Fruit Weights (Sample Size = 20)")
plt.xlabel("Weight (grams)")
plt.ylabel("Frequency")
plt.show()

mean_b = np.mean(data_b)
std_b = np.std(data_b)
print("Giá trị trung bình (mẫu 20):", mean_b)
print("Độ lệch chuẩn (mẫu 20):", std_b)

#c
data_c = norm.rvs(loc=mu, scale=sigma, size=100)
plt.hist(data_c, bins=10, width=dorongcot)
plt.title("Histogram of Fruit Weights (Sample Size = 100)")
plt.xlabel("Weight (grams)")
plt.ylabel("Frequency")
plt.show()
mean_c = np.mean(data_c)
std_c = np.std(data_c)
print("Giá trị trung bình (mẫu 100):", mean_c)
print("Độ lệch chuẩn (mẫu 100):", std_c)

#d
# Nhận xét: Khi kích thước mẫu tăng lên, giá trị trung bình và độ lệch chuẩn của mẫu càng gần với giá trị thực của phân phối chuẩn ban đầu (µ = 500, σ = 4). Điều này minh họa định lý giới hạn trung tâm, cho thấy rằng với kích thước mẫu lớn, phân phối mẫu sẽ xấp xỉ phân phối chuẩn.
# Out:
# Tỷ lệ loại 1 (trên 505 gam): 0.10564977366685535
# Tỷ lệ loại 2 (từ 495 – 505 gam): 0.7887004526662893
# Tỷ lệ loại 3 (dưới 495 gam): 0.10564977366685535
# Giá trị trung bình (mẫu 20): 500.52373929904206
# Độ lệch chuẩn (mẫu 20): 3.0026019787559206
# Giá trị trung bình (mẫu 100): 499.8537374580261
# Độ lệch chuẩn (mẫu 100): 3.699532127912813

# %% [markdown]
# **Bài 04:** Mô phỏng tung một con xúc sắc cân đối đồng chất 5000 lần. Dựa vào giá trị mô phỏng, bạn hãy tìm các giá trị xác suất dưới đây:
#
# a. Xác suất để  số chấm xuất hiện là 4
#
# b. Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4
#
# c. Giả sử biết số chấm xuất hiện lớn hơn hoặc bằng 4. Hãy tìm xác suất để mặt 6 chấm xuất hiện.

# %%
#a
data = np.random.randint(1, 7, size=5000)

prob_4 = np.sum(data == 4) / len(data)
print("Xác suất để số chấm xuất hiện là 4:", prob_4)
# b
prob_4b = np.sum(data >= 4) / len(data)
print("Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4:", prob_4b)
# c
data_4c = data[data >= 4]
prob_6_given_4 = np.sum(data_4c == 6) / len(data_4c)
print("Xác suất để mặt 6 chấm xuất hiện (biết số chấm >= 4):", prob_6_given_4)
# Out:
# Xác suất để số chấm xuất hiện là 4: 0.1656
# Xác suất để số chấm xuất hiện lớn hơn hoặc bằng 4: 0.4946
# Xác suất để mặt 6 chấm xuất hiện (biết số chấm >= 4): 0.3372422159320663

# %% [markdown]
# **Bài 05:** Tạo 5000 số ngẫu nhiên có phân phối nhị thức với n=50, p=0.7 Bạn Hãy
#
# a. Tìm các giá trị thống kê: min, max, Q1, Q2, Q3
#
# b. Vẽ đồ thị boxplot
#
# c. Vẽ các đồ thị: tần số, tần suất

# %%
# **Bài 05:** Tạo 5000 số ngẫu nhiên có phân phối nhị thức với n=50, p=0.7 Bạn Hãy

# a. Tìm các giá trị thống kê: min, max, Q1, Q2, Q3

# b. Vẽ đồ thị boxplot

# c. Vẽ các đồ thị: tần số, tần suất

data = binom.rvs(n=50, p=0.7, size=5000)
# a
min_value = np.min(data)
max_value = np.max(data)
Q1 = np.percentile(data, 25)
Q2 = np.percentile(data, 50)
Q3 = np.percentile(data, 75)

print("Min:", min_value)
print("Max:", max_value)
print("Q1:", Q1)
print("Q2 (Median):", Q2)
print("Q3:", Q3)
# b
plt.boxplot(data)
plt.title("Boxplot of Binomial Distribution (n=50, p=0.7)")
plt.ylabel("Value")
plt.show()
# c
# Tần số
plt.hist(data, bins=30, edgecolor='black')
plt.title("Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# Tần suất
plt.hist(data, bins=30, density=True, edgecolor='black')
plt.title("Relative Frequency Histogram")
plt.xlabel("Value")
plt.ylabel("Relative Frequency")
plt.show()
# Out:
# Min: 21
# Max: 45
# Q1: 33.0
# Q2 (Median): 35.0
# Q3: 37.0

# %% [markdown]
# **Bài 6**
#
# Giả sử X là biến ngẫu nhiên rời rạc
#
# a. Hãy cho biết ý nghĩa câu lệnh sau: `binom.pmf(4, 10, 0.6)`
#
# b. Giả sử X có phân phối nhị thức `X ~ B(10, 0.6)`. Hãy tính các giá trị sau:
# $P(X \leq 5), P(X \le 5), P(X \ge 4), P(X = 5) $
#
# c. Hãy cho biết ý nghĩa câu lệnh sau: `poisson.pmf(4, 3)`
#
# d. Giả sử X có phân phối Poisson `X ~ P(3)`. Hãy tính các giá trị sau:
# $P(X \leq 5), P(X \le 5), P(X \ge 4), P(X = 5) $

# %%
# **Bài 6**

# Giả sử X là biến ngẫu nhiên rời rạc

# a. Hãy cho biết ý nghĩa câu lệnh sau: `binom.pmf(4, 10, 0.6)`

# b. Giả sử X có phân phối nhị thức `X ~ B(10, 0.6)`. Hãy tính các giá trị sau:  
# $P(X \leq 5), P(X \le 5), P(X \ge 4), P(X = 5) $

# c. Hãy cho biết ý nghĩa câu lệnh sau: `poisson.pmf(4, 3)`

# d. Giả sử X có phân phối Poisson `X ~ P(3)`. Hãy tính các giá trị sau:  
# $P(X \leq 5), P(X \le 5), P(X \ge 4), P(X = 5) $

#a
# Ý nghĩa: Tính xác suất để biến ngẫu nhiên X có phân phối nhị thức với n=10 và p=0.6 nhận giá trị đúng bằng 4.

#b
n = 10
p = 0.6
data = binom(n, p)
P_X_le_5 = data.cdf(5)
P_X_ge_4 = 1 - data.cdf(3)
P_X_eq_5 = data.pmf(5)
print("P(X ≤ 5):", P_X_le_5)
print("P(X ≥ 4):", P_X_ge_4)
print("P(X = 5):", P_X_eq_5)
#c
# Ý nghĩa: Tính xác suất để biến ngẫu nhiên X có phân phối Poisson với λ=3 nhận giá trị đúng bằng 4.
# Out:
# P(X ≤ 5): 0.36689674240000025
# P(X ≥ 4): 0.9452381183999999
# P(X = 5): 0.2006581248

# %% [markdown]
# **Bài 7**
#
# a. Cho biết ý nghĩa của các câu lệnh sau:
#
# - `norm.cdf(2)`
#
# - `norm.cdf(2, 1, 1)`
#
# - `norm.cdf(2, 1, 2)`
#
# b. Cho biết kết quả của câu lệnh sau: `norm.ppf(norm.cdf(2))`
#
# c. Tính các giá trị sau và vẽ hình minh họa cho các giá trị tính được:
#
# - `norm.ppf(0.975)`
#
# - `norm.ppf(0.975, 1, 1)`
#
# - `norm.ppf(0.975, 1, 2)`
#
# d. Giả sử biến ngẫu nhiên X có phân phối chuẩn với kỳ vọng là 24 và phương sai là 16. Hãy tính các giá trị sau:
#
# - $P(X \leq 20)$
# - $P(X \ge 29.5)$
# - $P(X = 23.8)$

# %%
# **Bài 7**

# a. Cho biết ý nghĩa của các câu lệnh sau:

# - `norm.cdf(2)`

# - `norm.cdf(2, 1, 1)`

# - `norm.cdf(2, 1, 2)`

# b. Cho biết kết quả của câu lệnh sau: `norm.ppf(norm.cdf(2))`

# c. Tính các giá trị sau và vẽ hình minh họa cho các giá trị tính được:

# - `norm.ppf(0.975)`

# - `norm.ppf(0.975, 1, 1)`

# - `norm.ppf(0.975, 1, 2)`

# d. Giả sử biến ngẫu nhiên X có phân phối chuẩn với kỳ vọng là 24 và phương sai là 16. Hãy tính các giá trị sau:

# - $P(X \leq 20)$
# - $P(X \ge 29.5)$
# - $P(X = 23.8)$

#a
# - `norm.cdf(2)`: Tính hàm phân phối tích lũy (CDF) của phân phối chuẩn chuẩn hóa tại điểm 2.
# - `norm.cdf(2, 1, 1)`: Tính CDF của phân phối chuẩn với trung bình 1 và độ lệch chuẩn 1 tại điểm 2.
# - `norm.cdf(2, 1, 2)`: Tính CDF của phân phối chuẩn với trung bình 1 và độ lệch chuẩn 2 tại điểm 2.

#b
result_b = norm.ppf(norm.cdf(2))
print("Kết quả của norm.ppf(norm.cdf(2)):", result_b)

#c 
ppf_975 = norm.ppf(0.975)
ppf_975_1_1 = norm.ppf(0.975, 1, 1)
ppf_975_1_2 = norm.ppf(0.975, 1, 2)
print("norm.ppf(0.975):", ppf_975)
print("norm.ppf(0.975, 1, 1):", ppf_975_1_1)
print("norm.ppf(0.975, 1, 2):", ppf_975_1_2)
# Vẽ hình minh họa
x = np.linspace(-4, 4, 1000)
plt.plot(x, norm.pdf(x), label='Standard Normal PDF')
plt.axvline(ppf_975, color='r', linestyle='--', label='norm.ppf(0.975)')
plt.axvline(ppf_975_1_1, color='g', linestyle='--', label='norm.ppf(0.975, 1, 1)')
plt.axvline(ppf_975_1_2, color='b', linestyle='--', label='norm.ppf(0.975, 1, 2)')
plt.title("Illustration of norm.ppf values")
plt.xlabel("x")
plt.ylabel("Density")
plt.legend()
plt.show()
#d
mu = 24
sigma = 4  # Độ lệch chuẩn là căn bậc hai của phương
# - P(X ≤ 20)
P_X_le_20 = norm.cdf(20, mu, sigma)
print("P(X ≤ 20):", P_X_le_20)
# - P(X ≥ 29.5)
P_X_ge_29_5 = 1 - norm.cdf(29.5, mu, sigma)
print("P(X ≥ 29.5):", P_X_ge_29_5)
# - P(X = 23.8)
P_X_eq_23_8 = norm.pdf(23.8, mu, sigma)
print("P(X = 23.8):", P_X_eq_23_8)
# Out:
# Kết quả của norm.ppf(norm.cdf(2)): 2.0000000000000004
# norm.ppf(0.975): 1.959963984540054
# norm.ppf(0.975, 1, 1): 2.959963984540054
# norm.ppf(0.975, 1, 2): 4.919927969080108
# P(X ≤ 20): 0.15865525393145707
# P(X ≥ 29.5): 0.08456572235133564
# P(X = 23.8): 0.09961097852369101

# %% [markdown]
# **Bài 8**
#
# Một công ty sản xuất làm ra các chi tiết máy với độ dài các chi tiết có phân phối chuẩn với kỳ vọng là 3000 mm và độ lệch chuẩn là 3 mm. Yêu cầu cho các chi tiết máy này là phải có chiều dài từ 2993 mm đến 3007 mm. Tính tỷ lệ sản phẩm lỗi của công ty

# %%
# **Bài 8**

# Một công ty sản xuất làm ra các chi tiết máy với độ dài các chi tiết có phân phối chuẩn với kỳ vọng là 3000 mm và độ lệch chuẩn là 3 mm. Yêu cầu cho các chi tiết máy này là phải có chiều dài từ 2993 mm đến 3007 mm. Tính tỷ lệ sản phẩm lỗi của công ty

mu = 3000  # Kỳ vọng
sigma = 3   # Độ lệch chuẩn

data = norm(loc=mu, scale=sigma)
p_within_spec = data.cdf(3007) - data.cdf(2993)
p_defective = 1 - p_within_spec
print("Tỷ lệ sản phẩm lỗi của công ty:", p_defective)
# Out:
# Tỷ lệ sản phẩm lỗi của công ty: 0.01963065725729063

# %% [markdown]
# **Bài 9**
#
# Giả sử điểm thi TOEIC là một biến ngẫu nhiên có phân phối chuẩn với kỳ vọng là 500, độ lệch chuẩn là 8. Bạn hãy:
#
# a. Mô phỏng bằng cách phát sinh ngẫu nhiên điểm thi TOIEC của một nhóm gồm 50 người.
#
# b. Tính điểm trung bình và độ lệch chuẩn về điểm của nhóm.
#
# c. Tìm miền giá trị, và miền phân vị (IQR) của nhóm
#
# d. Cho biết tỷ lệ đạt trên 450 điểm của nhóm.
#
# e. Vẽ đồ thị histogram của nhóm và so sánh với đồ thị hàm mật độ của phân phối chuẩn với kỳ vọng là 500 và độ lệch chuẩn là 8.
#
# f. Thay vì mô phỏng 50 người, hãy mô phỏng nhóm với 100 người thi. Bạn có nhận xét gì?

# %%
# **Bài 9**

# Giả sử điểm thi TOEIC là một biến ngẫu nhiên có phân phối chuẩn với kỳ vọng là 500, độ lệch chuẩn là 8. Bạn hãy:

# a. Mô phỏng bằng cách phát sinh ngẫu nhiên điểm thi TOIEC của một nhóm gồm 50 người.

# b. Tính điểm trung bình và độ lệch chuẩn về điểm của nhóm.

# c. Tìm miền giá trị, và miền phân vị (IQR) của nhóm

# d. Cho biết tỷ lệ đạt trên 450 điểm của nhóm. 

# e. Vẽ đồ thị histogram của nhóm và so sánh với đồ thị hàm mật độ của phân phối chuẩn với kỳ vọng là 500 và độ lệch chuẩn là 8.

# f. Thay vì mô phỏng 50 người, hãy mô phỏng nhóm với 100 người thi. Bạn có nhận xét gì?

mu = 500  # Kỳ vọng
sigma = 8   # Độ lệch chuẩn

# a
data = norm.rvs(loc=mu, scale=sigma, size=50)
# b
mean_score = np.mean(data)
std_score = np.std(data)
print("Điểm trung bình của nhóm:", mean_score)
print("Độ lệch chuẩn về điểm của nhóm:", std_score)
# c
Q1 = np.percentile(data, 25)
Q2 = np.percentile(data, 50)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
print("Miền giá trị (IQR) của nhóm:", IQR)
# d
p_above_450 = 1 - norm.cdf(450, mu, sigma)
print("Tỷ lệ đạt trên 450 điểm của nhóm:", p_above_450)
# e
plt.hist(data, bins=10, density=True, alpha=0.6, color='g')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
plt.plot(x, p, 'k', linewidth=2)
plt.title("Histogram of TOEIC Scores with Normal Distribution Overlay")
plt.xlabel("TOEIC Score")
plt.ylabel("Density")
plt.show()

# f
data_100 = norm.rvs(loc=mu, scale=sigma, size=100)
mean_score_100 = np.mean(data_100)
std_score_100 = np.std(data_100)
print("Điểm trung bình của nhóm 100 người:", mean_score_100)
print("Độ lệch chuẩn về điểm của nhóm 100 người:", std_score_100)
# Nhận xét: Khi kích thước mẫu tăng từ 50 lên 100, giá trị trung bình và độ lệch chuẩn của mẫu có xu hướng gần hơn với giá trị thực của phân phối chuẩn ban đầu (µ = 500, σ = 8). Điều này minh họa định lý giới hạn trung tâm, cho thấy rằng với kích thước mẫu lớn, phân phối mẫu sẽ xấp xỉ phân phối chuẩn.
# Out:
# Điểm trung bình của nhóm: 497.7130151407553
# Độ lệch chuẩn về điểm của nhóm: 6.641085087055777
# Miền giá trị (IQR) của nhóm: 9.9927791490868
# Tỷ lệ đạt trên 450 điểm của nhóm: 0.9999999997947736
# Điểm trung bình của nhóm 100 người: 500.70334488865774
# Độ lệch chuẩn về điểm của nhóm 100 người: 8.684583506682978

# %% [markdown]
# **Bài 10**
#
# Viết một chương trình để mô phỏng việc tung đồng xu và đánh giá phương sai của giá trị mô phỏng của biến ngẫu nhiên X (tung được mặt `Head`) đối với các số lần tung khác nhau. Giả sử  đồng xu phải cân bằng.
#
# Đối với mỗi N từ 10; 40; 90; 160; 250; 490; 640; 810; 1000, hãy ước tính giá trị của X bằng cách mô phỏng số lần tung đó.
#
# Bạn nên chạy mỗi mô phỏng 100 lần và sử dụng tập hợp các ước tính để đánh giá phương sai của ước tính x của bạn. Vẽ biểu đồ phương sai này so với N, bạn có nhận xét gì không?

# %%
# **Bài 10**

# Viết một chương trình để mô phỏng việc tung đồng xu và đánh giá phương sai của giá trị mô phỏng của biến ngẫu nhiên X (tung được mặt `Head`) đối với các số lần tung khác nhau. Giả sử  đồng xu phải cân bằng. 

# Đối với mỗi N từ 10; 40; 90; 160; 250; 490; 640; 810; 1000, hãy ước tính giá trị của X bằng cách mô phỏng số lần tung đó. 

# Bạn nên chạy mỗi mô phỏng 100 lần và sử dụng tập hợp các ước tính để đánh giá phương sai của ước tính x của bạn. Vẽ biểu đồ phương sai này so với N, bạn có nhận xét gì không?

import numpy as np
import matplotlib.pyplot as plt
N_values = [10, 40, 90, 160, 250, 490, 640, 810, 1000]
variances = []
for N in N_values:
    estimates = []
    for _ in range(100):
        flips = np.random.choice(['H', 'T'], size=N)
        X_hat = np.sum(flips == 'H') / N
        estimates.append(X_hat)
    variance = np.var(estimates)
    variances.append(variance)
plt.plot(N_values, variances, marker='o')
plt.title("Variance of Estimate X vs Number of Flips N")
plt.xlabel("Number of Flips N")
plt.ylabel("Variance of Estimate X")
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.show()
# Nhận xét: Khi số lần tung N tăng lên, phương sai của ước tính X giảm xuống. Điều này minh họa rằng với kích thước mẫu lớn hơn, ước tính trở nên ổn định hơn và gần với giá trị thực của biến ngẫu nhiên.

# %% [markdown]
# ---
